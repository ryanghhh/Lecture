# %%
import os
import numpy as np
import pandas as pd
from sklearn.linear_model import LabelEncoder

# %%
DATA_DIR = os.getcwd()  # put train.csv/test.csv in the same folder as this notebook
TRAIN_PATH = os.path.join(DATA_DIR, 'train.csv')
TEST_PATH  = os.path.join(DATA_DIR, 'test.csv')

# %%
train_path = r'C:\Users\1\Desktop\대학원\1-1\머신러닝과 응용\과제\train.csv'
test_path = r'C:\Users\1\Desktop\대학원\1-1\머신러닝과 응용\과제\test.csv'

train_data = pd.read_csv(train_path)
test_data = pd.read_csv(test_path)

print('Train shape:', train_data.shape)
print('Test shape:', test_data.shape)
display(train_data.head(20))
display(test_data.head(10))
# Out:
# Train shape: (32950, 21)
# Test shape: (8238, 20)
#        id  age          job   marital            education  default  housing  \
# 0   19495   36   technician   married    university.degree       no      yes
# 1   38793   28       admin.    single    university.degree       no      yes
# 2   27160   57   management  divorced  professional.course       no      yes
# 3   36476   24  blue-collar    single             basic.9y       no  unknown
# 4   38007   24      student    single             basic.9y       no  unknown
# 5   16823   54   technician   married          high.school  unknown      yes
# 6   35400   25  blue-collar    single             basic.9y       no       no
# 7   15785   43       admin.   married          high.school       no      yes
# 8   27842   56      retired   married    university.degree       no      yes
# 9   25906   30  blue-collar   married             basic.9y       no      yes
# ...

# %%
train_data.keys()
# Out:
# Index(['id', 'age', 'job', 'marital', 'education', 'default', 'housing',
#        'loan', 'contact', 'month', 'day_of_week', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
print('\nTarget distribution (y):')
print(train_data['y'].value_counts(dropna=False))

print('\nMissing values per column (train):')
print(train_data.isna().sum())
# Out:
# Target distribution (y):
# y
# no     29238
# yes     3712
# Name: count, dtype: int64
#
# Missing values per column (train):
# id                0
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
print('\nUnknown label counts in categorical columns (train_data):')
cat_cols_all = ['job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome']
for c in cat_cols_all:
    if c in train_data.columns:
        unk = (train_data[c].astype(str).str.lower() == 'unknown').sum()
        print(f'{c}: {unk}')
# Out:
# Unknown label counts in categorical columns (train_data):
# job: 262
# marital: 62
# education: 1371
# default: 6859
# housing: 790
# loan: 790
# contact: 0
# month: 0
# day_of_week: 0
# poutcome: 0

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(handle_unknown='ignore')

# %%
train_data['job'] = train_data['job'].astype('category')
train_data['marital'] = train_data['marital'].astype('category')
train_data['education'] = train_data['education'].astype('category')
train_data['default'] = train_data['default'].astype('category')
train_data['housing'] = train_data['housing'].astype('category')
train_data['contact'] = train_data['contact'].astype('category')
train_data['month'] = train_data['month'].astype('category')
train_data['day_of_week'] = train_data['day_of_week'].astype('category')
train_data['poutcome'] = train_data['poutcome'].astype('category')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32950 entries, 0 to 32949
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              32950 non-null  int64
#  1   age             32950 non-null  int64
#  2   job             32950 non-null  category
#  3   marital         32950 non-null  category
#  4   education       32950 non-null  category
#  5   default         32950 non-null  category
#  6   housing         32950 non-null  category
#  7   loan            32950 non-null  object
#  8   contact         32950 non-null  category
#  9   month           32950 non-null  category
#  10  day_of_week     32950 non-null  category
#  11  campaign        32950 non-null  int64
#  12  pdays           32950 non-null  int64
#  13  previous        32950 non-null  int64
#  14  poutcome        32950 non-null  category
#  15  emp.var.rate    32950 non-null  float64
# ...

# %%
train_data['y'] = train_data['y'].map({'yes': 1, 'no': 0})

# %%
df = pd.DataFrame(train_data)
df.head()
# Out:
#       id  age          job   marital            education default  housing  \
# 0  19495   36   technician   married    university.degree      no      yes
# 1  38793   28       admin.    single    university.degree      no      yes
# 2  27160   57   management  divorced  professional.course      no      yes
# 3  36476   24  blue-collar    single             basic.9y      no  unknown
# 4  38007   24      student    single             basic.9y      no  unknown
#
#       loan   contact month  ... campaign  pdays  previous     poutcome  \
# 0      yes  cellular   aug  ...        1    999         0  nonexistent
# 1       no  cellular   nov  ...        2    999         0  nonexistent
# 2       no  cellular   nov  ...        1    999         0  nonexistent
# 3  unknown  cellular   jun  ...        1    999         0  nonexistent
# 4  unknown  cellular   sep  ...        1    999         0  nonexistent
#
#   emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %%
df.describe()
# Out:
#                  id           age      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean   20572.367527     40.010561      2.569347    962.383338      0.172049
# std    11887.028106     10.415313      2.774591    187.141359      0.492613
# min        1.000000     17.000000      1.000000      0.000000      0.000000
# 25%    10272.250000     32.000000      1.000000    999.000000      0.000000
# 50%    20587.000000     38.000000      2.000000    999.000000      0.000000
# 75%    30854.750000     47.000000      3.000000    999.000000      0.000000
# max    41187.000000     98.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m  \
# count  32950.000000    32950.000000   32950.000000  32950.000000
# mean       0.081873       93.574727     -40.502194      3.623780
# std        1.572049        0.579442       4.631271      1.732958
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_data['job_data_'])
